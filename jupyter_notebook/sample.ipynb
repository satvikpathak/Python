# %%
# %pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 2.1 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/11.5 MB 2.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.6/11.5 MB 2.2 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/11.5 MB 2.3 MB/s eta 0:00:05
#    -------- ------------------------------- 2.4/11.5 MB 2.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.9/11.5 MB 2.3 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.4/11.5 MB 2.3 MB/s eta 0:00:04
#    ------------- -------------------------- 3.9/11.5 MB 2.3 MB/s eta 0:00:04
#    -------------- ------------------------- 4.2/11.5 MB 2.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.7/11.5 MB 2.3 MB/s eta 0:00:03
# ...

# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# ## Intro
# Two primary data structures in pandas are Series and DataFrame.
# ### Series
# * 1 dimensional
# ### DataFrame
# * 2 dimensional

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})

# %%
df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df = pd.read_csv('../finance_data.csv')

# %%
df
# Out:
#           date    amount category        description
# 0   11-11-2024  500000.0   Income             Salary
# 1   12-12-2005     456.0  Expense              hello
# 2   15-01-2023    1500.0  Expense          Groceries
# 3   03-02-2024   30000.0   Income     Freelance Work
# 4   18-03-2023     800.0  Expense          Transport
# 5   25-04-2024  125000.0   Income              Bonus
# 6   07-05-2024    1000.0  Expense          Utilities
# 7   12-06-2024     200.0  Expense        Coffee Shop
# 8   22-07-2024    5000.0  Expense           Shopping
# 9   01-08-2024   15000.0   Income  Investment Return
# 10  15-09-2024     750.0  Expense      Internet Bill
# 11  11-10-2024   10000.0   Income    Stock Dividends
# 12  22-10-2024     200.0  Expense       Subscription
# 13  05-11-2024    1500.0  Expense            Medical
# 14  31-12-2024    2500.0  Expense         Dining Out
# 15  01-01-2025  200000.0   Income             Salary
# 16  14-02-2025     300.0  Expense              Books
# ...

# %%
df.head()
# Out:
#          date    amount category     description
# 0  11-11-2024  500000.0   Income          Salary
# 1  12-12-2005     456.0  Expense           hello
# 2  15-01-2023    1500.0  Expense       Groceries
# 3  03-02-2024   30000.0   Income  Freelance Work
# 4  18-03-2023     800.0  Expense       Transport

# %%
df.tail()
# Out:
#           date    amount category        description
# 15  01-01-2025  200000.0   Income             Salary
# 16  14-02-2025     300.0  Expense              Books
# 17  20-03-2025    2500.0  Expense      Entertainment
# 18  15-04-2025   40000.0   Income  Freelance Project
# 19  30-05-2025     600.0  Expense    Mobile Recharge

# %%
df.describe()
# Out:
#               amount
# count      20.000000
# mean    46865.300000
# std    118002.634572
# min       200.000000
# 25%       712.500000
# 50%      2000.000000
# 75%     18750.000000
# max    500000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         20 non-null     object
#  1   amount       20 non-null     float64
#  2   category     20 non-null     object
#  3   description  20 non-null     object
# dtypes: float64(1), object(3)
# memory usage: 772.0+ bytes

# %% [markdown]
# # Data Selection

# %%
df["date"]
# Out:
# 0     11-11-2024
# 1     12-12-2005
# 2     15-01-2023
# 3     03-02-2024
# 4     18-03-2023
# 5     25-04-2024
# 6     07-05-2024
# 7     12-06-2024
# 8     22-07-2024
# 9     01-08-2024
# 10    15-09-2024
# 11    11-10-2024
# 12    22-10-2024
# 13    05-11-2024
# 14    31-12-2024
# 15    01-01-2025
# 16    14-02-2025
# 17    20-03-2025
# 18    15-04-2025
# 19    30-05-2025
# Name: date, dtype: object

# %%
type(df["date"])
# Out:
# pandas.core.series.Series

# %%
df[["date", "amount", "category"]]
# Out:
#           date    amount category
# 0   11-11-2024  500000.0   Income
# 1   12-12-2005     456.0  Expense
# 2   15-01-2023    1500.0  Expense
# 3   03-02-2024   30000.0   Income
# 4   18-03-2023     800.0  Expense
# 5   25-04-2024  125000.0   Income
# 6   07-05-2024    1000.0  Expense
# 7   12-06-2024     200.0  Expense
# 8   22-07-2024    5000.0  Expense
# 9   01-08-2024   15000.0   Income
# 10  15-09-2024     750.0  Expense
# 11  11-10-2024   10000.0   Income
# 12  22-10-2024     200.0  Expense
# 13  05-11-2024    1500.0  Expense
# 14  31-12-2024    2500.0  Expense
# 15  01-01-2025  200000.0   Income
# 16  14-02-2025     300.0  Expense
# 17  20-03-2025    2500.0  Expense
# 18  15-04-2025   40000.0   Income
# 19  30-05-2025     600.0  Expense

# %%
df.iloc[3]
# Out:
# date               03-02-2024
# amount                30000.0
# category               Income
# description    Freelance Work
# Name: 3, dtype: object

# %%
type(df.iloc[3])
# Out:
# pandas.core.series.Series

# %%
df2 = pd.read_csv("../fd2.csv")

# %%
df2.head()
# Out:
#          date    amount category     description
# 0  11-11-2024  500000.0   Income          Salary
# 1         NaN     456.0      NaN           hello
# 2  15-01-2023    1500.0  Expense             NaN
# 3  03-02-2024   30000.0   Income  Freelance Work
# 4         NaN     800.0  Expense       Transport

# %%
df2.dropna()
# Out:
#           date    amount category        description
# 0   11-11-2024  500000.0   Income             Salary
# 3   03-02-2024   30000.0   Income     Freelance Work
# 5   25-04-2024  125000.0   Income              Bonus
# 6   07-05-2024    1000.0  Expense          Utilities
# 7   12-06-2024     200.0  Expense        Coffee Shop
# 9   01-08-2024   15000.0   Income  Investment Return
# 10  15-09-2024     750.0  Expense      Internet Bill
# 12  22-10-2024     200.0  Expense       Subscription
# 13  05-11-2024    1500.0  Expense            Medical
# 14  31-12-2024    2500.0  Expense         Dining Out
# 15  01-01-2025  200000.0   Income             Salary
# 16  14-02-2025     300.0  Expense              Books
# 17  20-03-2025    2500.0  Expense      Entertainment
# 18  15-04-2025   40000.0   Income  Freelance Project
# 19  30-05-2025     600.0  Expense    Mobile Recharge

# %%
df2.fillna(0)
# Out:
#           date    amount category        description
# 0   11-11-2024  500000.0   Income             Salary
# 1            0     456.0        0              hello
# 2   15-01-2023    1500.0  Expense                  0
# 3   03-02-2024   30000.0   Income     Freelance Work
# 4            0     800.0  Expense          Transport
# 5   25-04-2024  125000.0   Income              Bonus
# 6   07-05-2024    1000.0  Expense          Utilities
# 7   12-06-2024     200.0  Expense        Coffee Shop
# 8   22-07-2024       0.0  Expense           Shopping
# 9   01-08-2024   15000.0   Income  Investment Return
# 10  15-09-2024     750.0  Expense      Internet Bill
# 11  11-10-2024   10000.0        0    Stock Dividends
# 12  22-10-2024     200.0  Expense       Subscription
# 13  05-11-2024    1500.0  Expense            Medical
# 14  31-12-2024    2500.0  Expense         Dining Out
# 15  01-01-2025  200000.0   Income             Salary
# 16  14-02-2025     300.0  Expense              Books
# ...

# %%
df2.rename(columns={"amount": "rokda"})
# Out:
#           date     rokda category        description
# 0   11-11-2024  500000.0   Income             Salary
# 1          NaN     456.0      NaN              hello
# 2   15-01-2023    1500.0  Expense                NaN
# 3   03-02-2024   30000.0   Income     Freelance Work
# 4          NaN     800.0  Expense          Transport
# 5   25-04-2024  125000.0   Income              Bonus
# 6   07-05-2024    1000.0  Expense          Utilities
# 7   12-06-2024     200.0  Expense        Coffee Shop
# 8   22-07-2024       NaN  Expense           Shopping
# 9   01-08-2024   15000.0   Income  Investment Return
# 10  15-09-2024     750.0  Expense      Internet Bill
# 11  11-10-2024   10000.0      NaN    Stock Dividends
# 12  22-10-2024     200.0  Expense       Subscription
# 13  05-11-2024    1500.0  Expense            Medical
# 14  31-12-2024    2500.0  Expense         Dining Out
# 15  01-01-2025  200000.0   Income             Salary
# 16  14-02-2025     300.0  Expense              Books
# ...

# %%
df2
# Out:
#           date    amount category        description
# 0   11-11-2024  500000.0   Income             Salary
# 1          NaN     456.0      NaN              hello
# 2   15-01-2023    1500.0  Expense                NaN
# 3   03-02-2024   30000.0   Income     Freelance Work
# 4          NaN     800.0  Expense          Transport
# 5   25-04-2024  125000.0   Income              Bonus
# 6   07-05-2024    1000.0  Expense          Utilities
# 7   12-06-2024     200.0  Expense        Coffee Shop
# 8   22-07-2024       NaN  Expense           Shopping
# 9   01-08-2024   15000.0   Income  Investment Return
# 10  15-09-2024     750.0  Expense      Internet Bill
# 11  11-10-2024   10000.0      NaN    Stock Dividends
# 12  22-10-2024     200.0  Expense       Subscription
# 13  05-11-2024    1500.0  Expense            Medical
# 14  31-12-2024    2500.0  Expense         Dining Out
# 15  01-01-2025  200000.0   Income             Salary
# 16  14-02-2025     300.0  Expense              Books
# ...
